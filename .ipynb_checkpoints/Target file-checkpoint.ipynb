# %%
import pandas as pd

# %%
df = pd.read_csv('stage_labels.csv')

# %%
df.loc[df['stage'] == "pN2"]
# Out:
#              patient stage
# 114  patient_019.zip   pN2
# 126  patient_021.zip   pN2
# 156  patient_026.zip   pN2
# 168  patient_028.zip   pN2
# 270  patient_045.zip   pN2
# 306  patient_051.zip   pN2
# 312  patient_052.zip   pN2
# 372  patient_062.zip   pN2
# 378  patient_063.zip   pN2
# 414  patient_069.zip   pN2
# 552  patient_092.zip   pN2
# 564  patient_094.zip   pN2
# 576  patient_096.zip   pN2
# 582  patient_097.zip   pN2

# %%
df.loc[df['stage'] == "pN1"]
# Out:
#              patient stage
# 72   patient_012.zip   pN1
# 78   patient_013.zip   pN1
# 84   patient_014.zip   pN1
# 90   patient_015.zip   pN1
# 96   patient_016.zip   pN1
# 102  patient_017.zip   pN1
# 108  patient_018.zip   pN1
# 120  patient_020.zip   pN1
# 132  patient_022.zip   pN1
# 174  patient_029.zip   pN1
# 198  patient_033.zip   pN1
# 204  patient_034.zip   pN1
# 234  patient_039.zip   pN1
# 252  patient_042.zip   pN1
# 264  patient_044.zip   pN1
# 282  patient_047.zip   pN1
# 390  patient_065.zip   pN1
# 396  patient_066.zip   pN1
# 420  patient_070.zip   pN1
# 432  patient_072.zip   pN1
# 438  patient_073.zip   pN1
# 450  patient_075.zip   pN1
# 456  patient_076.zip   pN1
# 462  patient_077.zip   pN1
# 480  patient_080.zip   pN1
# 504  patient_084.zip   pN1
# 546  patient_091.zip   pN1
# 558  patient_093.zip   pN1
# 570  patient_095.zip   pN1
# 594  patient_099.zip   pN1
