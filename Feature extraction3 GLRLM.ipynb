# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

import skimage.io as io
from skimage import data
from skimage.color import rgb2hed, hed2rgb
import matplotlib.patches as patches
from skimage import measure
from skimage.color import rgb2gray
from skimage.util import img_as_ubyte
from skimage import io
from skimage.feature import greycomatrix, greycoprops

# %% [markdown]
# # without applying filters

# %%
slide = io.imread("Camelyon_Dataset/Cancer/01_17_22.png", as_gray = True)

for i in range(0, len(slide)):
    for j in range(0, len(slide[i])):
        slide[i][j] = int(slide[i][j]*255)

plt.subplots(figsize = (15,15))
io.imshow(slide)

# %% [markdown]
# ## filter method #1

# %%
from skimage import filters
from skimage.morphology import disk
slide = io.imread("Camelyon_Dataset/Cancer/01_17_22.png", as_gray = True)
for i in range(0, 3):
    slide = filters.median(slide, disk(1))
    slide = filters.median(slide, disk(2))

plt.subplots(figsize = (15,15))
io.imshow(slide)

for i in range(0, len(slide)):
    for j in range(0, len(slide[i])):
        slide[i][j] = int(slide[i][j]*255)

# %% [markdown]
# # filter method #2

# %%
from skimage import filters
from skimage.morphology import disk
slide = io.imread("Camelyon_Dataset/Cancer/01_17_22.png", as_gray = True)
for i in range(0, 3):
    slide = filters.median(slide, disk(2))
    slide = filters.median(slide, disk(1))

plt.subplots(figsize = (15,15))
io.imshow(slide)


for i in range(0, len(slide)):
    for j in range(0, len(slide[i])):
        slide[i][j] = int(slide[i][j]*255)
io.imshow(slide)

# %% [markdown]
# # filter method #3

# %%
from skimage import filters
from skimage.morphology import disk
slide = io.imread("Camelyon_Dataset/Cancer/01_17_22.png", as_gray = True)
for i in range(0, 3):
    slide = filters.median(slide, disk(2))
    slide = filters.median(slide, disk(1))

for i in range(0, 50):
    slide = filters.median(slide, disk(1))

plt.subplots(figsize = (15,15))
io.imshow(slide)


for i in range(0, len(slide)):
    for j in range(0, len(slide[i])):
        slide[i][j] = int(slide[i][j]*255)

# %% [markdown]
# # filter method #4

# %%
# filter method #3
from skimage import filters
from skimage.morphology import disk
slide = io.imread("Camelyon_Dataset/Cancer/01_17_22.png", as_gray = True)

# slide = filters.median(slide, disk(3))

for i in range(0, 50):
    slide = filters.median(slide, disk(1))

plt.subplots(figsize = (15,15))
io.imshow(slide)


for i in range(0, len(slide)):
    for j in range(0, len(slide[i])):
        slide[i][j] = int(slide[i][j]*255)

# %%
# slide = slide.flatten().reshape((512*512,3))
# from skimage import io, measure
# from sklearn.acluster import KMeans

# estimator = KMeans(n_clusters=4, n_init=1, init='random')

# estimator.fit(slide)
# labels = estimator.labels_
# print(labels.shape)

# label_image = np.reshape(labels, (512, 512))

# redChannel = slide[:,:,0]
# greenChannel = slide[:,:,1]
# blueChannel = slide[:,:,2]

# %%
BLACK = 70
bin_size = 10
# ["0-10", "11-20", "21-30", "31-40", "41-50", "51-60", "61-70"]
bins = ("0-10", "11-20", "21-30", "31-40", "41-50", "51-60", "61-70")

# %%
glrlm = getGrayLevelRumatrix(slide, ["deg0"])

color = []
length = []
len_2 = [0, 0, 0, 0, 0, 0, 0]
len_3 = [0, 0, 0, 0, 0, 0, 0]
len_4 = [0, 0, 0, 0, 0, 0, 0]
len_5 = [0, 0, 0, 0, 0, 0, 0]
len_6 = [0, 0, 0, 0, 0, 0, 0]
len_7 = [0, 0, 0, 0, 0, 0, 0]
len_8 = [0, 0, 0, 0, 0, 0, 0]
for num in range(0, BLACK):
    color.append(num)
    length.append(np.argmax(glrlm[num])+1)
    bin_num = num // bin_size
    len_2[bin_num] += int(glrlm[num][1])
    len_3[bin_num] += int(glrlm[num][2])
    len_4[bin_num] += int(glrlm[num][3])
    len_5[bin_num] += int(glrlm[num][4])
    len_6[bin_num] += int(glrlm[num][5])
    len_7[bin_num] += int(glrlm[num][6])
    len_8[bin_num] += int(glrlm[num][7])
    
plt.subplots(3,2, figsize = (20,20))
plt.suptitle("0 degree GLRLM" , fontsize = 28)
plt.tight_layout(pad=10.0)

plt.subplot(4,2,1)
plt.plot(color, length)
plt.title("maximum length for each color type", fontsize = 14)
plt.xlabel("color", fontsize = 14)
plt.ylabel("maximum length", fontsize = 14)






# length = 2
plt.subplot(4,2,2)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_2)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=2 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)





# length = 3
plt.subplot(4,2,3)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_3)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=3 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)



# length = 4
plt.subplot(4,2,4)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_4)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=4 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)




# length = 5
plt.subplot(4,2,5)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_5)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=5 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)




# length = 6
plt.subplot(4,2,6)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_6)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=6 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)





# length = 6
plt.subplot(4,2,7)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_7)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=7 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)




# length = 6
plt.subplot(4,2,8)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_8)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=8 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)
# Out:
# 236.0 17.0
# Text(0, 0.5, 'count')

# %%
glrlm = getGrayLevelRumatrix(slide, ["deg45"])

color = []
length = []
len_2 = [0, 0, 0, 0, 0, 0, 0]
len_3 = [0, 0, 0, 0, 0, 0, 0]
len_4 = [0, 0, 0, 0, 0, 0, 0]
len_5 = [0, 0, 0, 0, 0, 0, 0]
len_6 = [0, 0, 0, 0, 0, 0, 0]
for num in range(0, BLACK):
    color.append(num)
    length.append(np.argmax(glrlm[num])+1)
    bin_num = num // bin_size
    len_2[bin_num] += int(glrlm[num][1])
    len_3[bin_num] += int(glrlm[num][2])
    len_4[bin_num] += int(glrlm[num][3])
    len_5[bin_num] += int(glrlm[num][4])
    len_6[bin_num] += int(glrlm[num][5])
    
plt.subplots(3,2, figsize = (20,20))
plt.suptitle("45 degree GLRLM" , fontsize = 28)

plt.subplot(3,2,1)
plt.plot(color, length)
plt.title("maximum length for each color type", fontsize = 14)
plt.xlabel("color", fontsize = 14)
plt.ylabel("maximum length", fontsize = 14)






# length = 2
plt.subplot(3,2,2)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_2)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=2 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)





# length = 3
plt.subplot(3,2,3)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_3)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=3 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)



# length = 4
plt.subplot(3,2,4)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_4)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=4 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)




# length = 5
plt.subplot(3,2,5)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_5)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=5 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)




# length = 6
plt.subplot(3,2,6)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_6)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=6 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)
# Out:
# 236.0 17.0
# Text(0, 0.5, 'count')

# %%
glrlm = getGrayLevelRumatrix(slide, ["deg90"])

color = []
length = []
len_2 = [0, 0, 0, 0, 0, 0, 0]
len_3 = [0, 0, 0, 0, 0, 0, 0]
len_4 = [0, 0, 0, 0, 0, 0, 0]
len_5 = [0, 0, 0, 0, 0, 0, 0]
len_6 = [0, 0, 0, 0, 0, 0, 0]
for num in range(0, BLACK):
    color.append(num)
    length.append(np.argmax(glrlm[num])+1)
    bin_num = num // bin_size
    len_2[bin_num] += int(glrlm[num][1])
    len_3[bin_num] += int(glrlm[num][2])
    len_4[bin_num] += int(glrlm[num][3])
    len_5[bin_num] += int(glrlm[num][4])
    len_6[bin_num] += int(glrlm[num][5])
    
plt.subplots(3,2, figsize = (20,20))
plt.suptitle("90 degree GLRLM" , fontsize = 28)

plt.subplot(3,2,1)
plt.plot(color, length)
plt.title("maximum length for each color type", fontsize = 14)
plt.xlabel("color", fontsize = 14)
plt.ylabel("maximum length", fontsize = 14)






# length = 2
plt.subplot(3,2,2)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_2)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=2 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)





# length = 3
plt.subplot(3,2,3)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_3)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=3 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)



# length = 4
plt.subplot(3,2,4)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_4)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=4 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)




# length = 5
plt.subplot(3,2,5)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_5)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=5 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)




# length = 6
plt.subplot(3,2,6)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_6)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=6 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)
# Out:
# 236.0 17.0
# Text(0, 0.5, 'count')

# %%
glrlm = getGrayLevelRumatrix(slide, ["deg135"])

color = []
length = []
len_2 = [0, 0, 0, 0, 0, 0, 0]
len_3 = [0, 0, 0, 0, 0, 0, 0]
len_4 = [0, 0, 0, 0, 0, 0, 0]
len_5 = [0, 0, 0, 0, 0, 0, 0]
len_6 = [0, 0, 0, 0, 0, 0, 0]
for num in range(0, BLACK):
    color.append(num)
    length.append(np.argmax(glrlm[num])+1)
    bin_num = num // bin_size
    len_2[bin_num] += int(glrlm[num][1])
    len_3[bin_num] += int(glrlm[num][2])
    len_4[bin_num] += int(glrlm[num][3])
    len_5[bin_num] += int(glrlm[num][4])
    len_6[bin_num] += int(glrlm[num][5])
    
plt.subplots(3,2, figsize = (20,20))
plt.suptitle("135 degree GLRLM " , fontsize = 28)

plt.subplot(3,2,1)
plt.plot(color, length)
plt.title("maximum length for each color type", fontsize = 14)
plt.xlabel("color", fontsize = 14)
plt.ylabel("maximum length", fontsize = 14)




# length = 2
plt.subplot(3,2,2)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_2)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=2 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)





# length = 3
plt.subplot(3,2,3)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_3)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=3 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)



# length = 4
plt.subplot(3,2,4)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_4)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=4 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)




# length = 5
plt.subplot(3,2,5)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_5)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=5 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)




# length = 6
plt.subplot(3,2,6)
y_pos = np.arange(len(bins))
plt.bar(y_pos, len_6)

plt.xticks(y_pos, bins, fontsize='14')
plt.title("count for length=6 of each color", fontsize = 14)
plt.xlabel("color range", fontsize = 14)
plt.ylabel("count", fontsize = 14)
# Out:
# 236.0 17.0
# Text(0, 0.5, 'count')

# %%
from itertools import groupby
def getGrayLevelRumatrix(array, theta):
        '''
        计算给定图像的灰度游程矩阵
        参数：
        array: 输入，需要计算的图像
        theta: 输入，计算灰度游程矩阵时采用的角度，list类型，可包含字段:['deg0', 'deg45', 'deg90', 'deg135']
        glrlm: 输出，灰度游程矩阵的计算结果
        '''
        P = array
        rows, cols = P.shape
        min_pixels = np.min(P)   # 图像中最小的像素值
        run_length = max(rows, cols)   # 像素的最大游行长度
        num_level = int(np.max(P) - np.min(P) + 1)   # 图像的灰度级数
        print(np.max(P), np.min(P))

        deg0 = [val.tolist() for sublist in np.vsplit(P, rows) for val in sublist]   # 0度矩阵统计
#         print("0 degree:", deg0)

        deg90 = [val.tolist() for sublist in np.split(np.transpose(P), cols) for val in sublist]   # 90度矩阵统计
#         print("90 degree:", deg90)
        
        diags = [P[::-1, :].diagonal(i) for i in range(-P.shape[0]+1, P.shape[1])]   #45度矩阵统计
#         print("45 degree:", diags)
        
        deg45 = [n.tolist() for n in diags]
        Pt = np.rot90(P, 3)   # 135度矩阵统计
        diags = [Pt[::-1, :].diagonal(i) for i in range(-Pt.shape[0]+1, Pt.shape[1])]
        deg135 = [n.tolist() for n in diags]

        def length(l):
            if hasattr(l, '__len__'):
                return np.size(l)
            else:
                i = 0
                for _ in l:
                    i += 1
                return i

        glrlm = np.zeros((num_level, run_length, len(theta)))   # 按照统计矩阵记录所有的数据， 第三维度表示计算角度
        for angle in theta:
            for splitvec in range(0, len(eval(angle))):
#                 print(eval(angle))
                flattened = eval(angle)[splitvec]
                answer = []
                for key, iter in groupby(flattened):   # 计算单个矩阵的像素统计信息
                    answer.append((key, length(iter)))   
                for ansIndex in range(0, len(answer)):
                    glrlm[int(answer[ansIndex][0]-min_pixels), int(answer[ansIndex][1]-1), theta.index(angle)] += 1   # 每次将统计像素值减去最小值就可以填入GLRLM矩阵中
        return glrlm
